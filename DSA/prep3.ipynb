# %% [markdown]
# ► Sorting
# - Count of Smaller Numbers After Self
# - First Missing Positive
#
#  ► Two Pointers
# - 3Sum
# - Sort Colors
# - Next Permutation
#
#  ► Prefix Sum and Line Sweep
# - Product of Array Except Self
# - Increment Submatrices by One
# - My Calendar II
#
#  ► Matrix
# - Rotate Image
# - Spiral Matrix
#
#  ► Hashing
# - Majority Element
# - Subarray Sum Equals K
#
#  ► Sliding Window
# - Subarray Product Less Than K
# - Frequency of the Most Frequent Element
# - Subarrays with K Different Integers
#
#  ► Linked List
# - Linked List Cycle II
# - Reverse Linked List
# - Sort List
# - Copy List with Random Pointer
# - Merge k Sorted Lists
# - LRU Cache
# - LFU Cache
#
#  ► Stack
# - Longest Valid Parentheses
# - Insert Intervals
# - Sum of Subarray Minimums
# - Trapping Rain Water
# - Largest Rectangle in Histogram
#
# Also, my 6-month Gen AI + DSA cohort has kicked off & we’re still getting enrollments.
# This is what’s included:
# → Live DSA sessions to build deep problem-solving skills
# → Gen AI module to stay ahead of the curve
# → Low-Level Design recordings for strong backend prep
# → And sessions with FAANG recruiters and engineers to understand how hiring works
#
# Check it out: https://lnkd.in/gJQZWGeh
# (The early offer is live right now.)
#
#  ► Queue
# - Queue using Two Stacks
# - Shortest Subarray with Sum at Least K
#
#  ► Binary Search
# - Search a 2D Matrix
# - Search in Rotated Sorted Array II
# - Koko Eating Bananas
# - Aggressive Cows
# - Median of Two Sorted Arrays
# - Kth Smallest Number in Multiplication Table
#
#  ► Bit Manipulation
# - Gray Code
# - XOR Queries of a Subarray
# - Find Longest Awesome Substring
#
#  ► Recursion and Backtracking
# - Sort a Stack
# - Permutations
# - Combination Sum II
# - N-Queens
# - Subsets
# - Rat in a Maze Problem
# - Sudoku Solver
#
#  ► Tree
# - Preorder, Postorder, Inorder in a single traverse
# - Construct Binary Tree from Preorder and Inorder Traversal
# - Binary Tree Right Side View
# - Vertical Order Traversal of a Binary Tree
# - All Nodes Distance K in Binary Tree
# - Binary Tree Maximum Path Sum
# - Lowest Common Ancestor of a Binary Tree
# - Minimum Distance Between BST Nodes
# - Recover Binary Search Tree
# - Lowest Common Ancestor of a Binary Search Tree
#
#  ► Heap
# - Task Scheduler
# - The Skyline Problem
# - Kth Largest Element in a Stream
# - Find Median from Data Stream
#
#  ► Greedy
# - Minimum Platforms
# - Fractional Knapsack
# - Job Sequencing Problem
# - Patching Array
# - Gas Station
#
# ► Dynamic Programming
# - Coin Change II
# - Partition Equal Subset Sum
# - Best Time to Buy and Sell Stock IV
# - Minimum Path Sum
# - Knapsack - 1
# - Knapsack - 2
# - Rod Cutting
# - Largest Divisible Subset
# - Longest Common Subsequence
# - Edit Distance
# - Count Square Submatrices with All Ones
# - Number of Submatrices That Sum to Target
# - Burst Balloons
# - Sum of Distances in Tree
# - Maximum Subarray
#
#  ► Graph
# - Clone Graph
# - Detect Cycles in 2D Grid
# - Is Graph Bipartite?
# - Course Schedule II
# - Count Sub Islands
# - Rotting Oranges
# - 01 Matrix
# - Investigation
# - Find the City With the Smallest Number of Neighbors at a Threshold Distance
# - Accounts Merge
# - Prim’s Minimum Spanning Tree (Theory)
# - Kruskal’s Minimum Spanning Tree (Theory)
#
#
#  ► Advanced Algorithms
# - KMP Algorithm for Pattern Searching (Theory)
# - Rabin-Karp Algorithm for Pattern Searching (Theory)
# - Z Algorithm (Theory)
# - Find Substring with Given Hash Value
# - Implement Trie (Prefix Tree)
# - Maximum XOR of Two Numbers in an Array
